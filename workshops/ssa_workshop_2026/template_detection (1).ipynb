# %%
import numpy as np
import eqcorrscan

from eqcorrscan import Tribe
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from obspy.core.event import (
    Catalog, Event, Pick, WaveformStreamID, Origin)
from obspy.geodetics import gps2dist_azimuth

# %% [markdown]
# ## Download a catalog of events
#
# For now, we're going to go with located events from July 17-19 2014 under Mount St. Helens (17 located events). If you want to adjust the dates or query, that should be obvious how to do so in the `client.get_events()` function.

# %%
client = Client("USGS")
catalog = client.get_events(
    starttime=UTCDateTime(2014, 7, 17),
    endtime=UTCDateTime(2014, 7, 19),
    latitude=46.2, longitude=-122.19,
    maxradius=0.25)

print(catalog)
# Out:
# 17 Event(s) in Catalog:
# 2014-07-18T22:48:15.530000Z | +46.201, -122.181 | -0.47 mh | manual
# 2014-07-18T21:34:55.770000Z | +46.199, -122.183 | 0.35 ml | manual
# ...
# 2014-07-17T13:23:06.160000Z | +46.425, -122.247 | 0.03 md | manual
# 2014-07-17T05:01:50.110000Z | +46.411, -122.260 | 0.09 md | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %% [markdown]
# Events at volcanoes are tough to locate, especially if they're small. If you don't have a template, you'll never find them with template detection. I used REDPy to see what else was going on around this time, and I'm going to take one event out of a family there and see what we can find with it.
#
# Event we'll use triggered at 2014-07-25T16:57:57.08. We don't have a location, so let's just assume it's near the summit at a depth of about 2 km b.s.l.

# %%
event_solo = Event()
event_solo.origins = [Origin()]
event_solo.origins[0].time = UTCDateTime('2014-07-25T16:57:57.08') - 2  # assume about 2 seconds from origin to trigger time
event_solo.origins[0].latitude = 46.2
event_solo.origins[0].longitude = -122.19
event_solo.origins[0].depth = 2000

# Append to the catalog
catalog += event_solo

print(catalog)
# Out:
# 18 Event(s) in Catalog:
# 2014-07-18T22:48:15.530000Z | +46.201, -122.181 | -0.47 mh | manual
# 2014-07-18T21:34:55.770000Z | +46.199, -122.183 | 0.35 ml | manual
# ...
# 2014-07-17T05:01:50.110000Z | +46.411, -122.260 | 0.09 md | manual
# 2014-07-25T16:57:55.080000Z | +46.200, -122.190
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %% [markdown]
# ## Make templates!
#
# Unfortunately, pick information for these earthquakes is not available to my knowledge through web queries (PNSN doesn't publish them with a nice API). Besides, they wouldn't have picked events on the temporary stations we want to use anyway.
#
# So what we're going to do is make a very rough estimate the P-wave arrival time at the locations of our stations of interest and use that as the start of our template window. If you were doing a big relative relocation study you'd work with actual pick times and shorter windows around P- and S-, but for sake of demonstration this is a good starting point if you're just looking to find more events.

# %%
# Get your inventory of stations (weak motion only, thus *HZ)
# We're going to go with a 0.25º radius around Mount St. Helens summit;
# you could go further out but this is stretching what's probably visible
# based on the magnitude of the events we're looking at...

client = Client("IRIS")
inventory = client.get_stations(starttime=UTCDateTime(2014, 7, 17),
    endtime=UTCDateTime(2014, 7, 19),
    latitude=46.2, longitude=-122.19,
    maxradius=0.25, channel='*HZ', level='channel')
print(inventory)
# Out:
# Inventory created at 2026-03-08T16:15:43.593600Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2014-07-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (4):
# 			CC, PB, UW, XD
# 		Stations (48):
# 			CC.JRO (Johnston Ridge Observatory)
# 			CC.SEP (September lobe, Mt. St. Helens (Dome sta))
# 			CC.STD (Studebaker Ridge, Mount St. Helens)
# 			CC.SUG (Sugar Bowl)
# 			CC.SWF2 (Southwest Flank 2, Mount St. Helens)
# 			CC.VALT (Vault, Mount St. Helens)
# 			PB.B201 (coldwt201bwa2007, Mt St Helens, WA, USA)
# 			PB.B202 (windyr202bwa2007, Mt St Helens, WA, USA)
# 			PB.B203 (quarry203bwa2007, Mount Saint Helens, WA, USA)
# 			PB.B204 (marble204bwa2007, Mt St Helens, WA, USA)
# 			UW.CDF (Cedar Flats, MSH, WA, USA)
# 			UW.EDM (East Dome, Mt. St. Helens, WA, USA)
# 			UW.ELK (Mt St Helens, Elk Rock, WA, USA)
# 			UW.FL2 (Flat Top 2, WA, USA)
# 			UW.HSR (South Ridge, Mt. St. Helens, WA, USA)
# 			UW.JUN (June Lake previous ISC code: JLK)
# 			UW.LVP (Lakeview Peak)
# 			UW.MTM (Mt. Mitchell, WA, USA)
# 			UW.SHW (Mt. St. Helens West, WA, USA)
# 			UW.SOS (Mt St Helens, Source of Smith Creek, WA, USA)
# 			UW.STD (Studebaker Ridge)
# 			UW.TDL (Tradedollar Lake, WA, USA)
# 			XD.MF05 (MF05)
# 			XD.MG03 (MG03)
# 			XD.MG05 (MG05)
# 			XD.MG06 (MG06)
# 			XD.MG07 (MG07)
# 			XD.MG08 (MG08)
# 			XD.MH04 (MH04)
# 			XD.MH07 (MH07)
# 			XD.MI04 (MI04)
# 			XD.MI05 (MI05)
# 			XD.MI07 (MI07)
# 			XD.MI08 (MI08)
# 			XD.MI09 (MI09)
# 			XD.MJ06 (MJ06)
# 			XD.MJ07 (MJ07)
# 			XD.MJ09 (MJ09)
# 			XD.MK04 (MK04)
# 			XD.MK06 (MK06)
# 			XD.MK07 (MK07)
# 			XD.MK08 (MK08)
# 			XD.ML07 (ML07)
# 			XD.ML09 (ML09)
# 			XD.MM04 (MM04)
# 			XD.MM06 (MM06)
# 			XD.MM08 (MM08)
# 			XD.MN07 (MN07)
# 		Channels (104):
# 			CC.JRO..BHZ, CC.SEP..EHZ, CC.STD..BHZ, CC.SUG..EHZ, CC.SWF2..BHZ,
# 			CC.VALT..BHZ, PB.B201..EHZ, PB.B201..LHZ, PB.B202..EHZ,
# 			PB.B202..LHZ, PB.B203..EHZ, PB.B203..LHZ, PB.B204..EHZ,
# 			PB.B204..LHZ, UW.CDF..EHZ, UW.EDM..EHZ, UW.ELK..EHZ, UW.FL2..EHZ,
# 			UW.HSR..EHZ, UW.JUN..EHZ, UW.LVP..EHZ, UW.MTM..EHZ, UW.SHW..EHZ,
# 			UW.SOS..EHZ, UW.STD..EHZ, UW.TDL..EHZ, XD.MF05..BHZ, XD.MF05..HHZ,
# 			XD.MF05..LHZ, XD.MG03..BHZ, XD.MG03..HHZ, XD.MG03..LHZ,
# 			XD.MG05..BHZ, XD.MG05..HHZ, XD.MG05..LHZ, XD.MG06..BHZ,
# 			XD.MG06..HHZ, XD.MG06..LHZ, XD.MG07..BHZ, XD.MG07..HHZ,
# 			XD.MG07..LHZ, XD.MG08..BHZ, XD.MG08..HHZ, XD.MG08..LHZ,
# 			XD.MH04..BHZ, XD.MH04..HHZ, XD.MH04..LHZ, XD.MH07..BHZ,
# 			XD.MH07..HHZ, XD.MH07..LHZ, XD.MI04..BHZ, XD.MI04..HHZ,
# 			XD.MI04..LHZ, XD.MI05..BHZ, XD.MI05..HHZ, XD.MI05..LHZ,
# 			XD.MI07..BHZ, XD.MI07..HHZ, XD.MI07..LHZ, XD.MI08..BHZ,
# 			XD.MI08..HHZ, XD.MI08..LHZ, XD.MI09..BHZ, XD.MI09..HHZ,
# 			XD.MI09..LHZ, XD.MJ06..BHZ, XD.MJ06..HHZ, XD.MJ06..LHZ,
# 			XD.MJ07..BHZ, XD.MJ07..HHZ, XD.MJ07..LHZ, XD.MJ09..BHZ,
# 			XD.MJ09..HHZ, XD.MJ09..LHZ, XD.MK04..BHZ, XD.MK04..HHZ,
# 			XD.MK04..LHZ, XD.MK06..BHZ, XD.MK06..HHZ, XD.MK06..LHZ,
# 			XD.MK07..BHZ, XD.MK07..HHZ, XD.MK07..LHZ, XD.MK08..BHZ,
# 			XD.MK08..HHZ, XD.MK08..LHZ, XD.ML07..BHZ, XD.ML07..HHZ,
# 			XD.ML07..LHZ, XD.ML09..BHZ, XD.ML09..HHZ, XD.ML09..LHZ,
# 			XD.MM04..BHZ, XD.MM04..HHZ, XD.MM04..LHZ, XD.MM06..BHZ,
# 			XD.MM06..HHZ, XD.MM06..LHZ, XD.MM08..BHZ, XD.MM08..HHZ,
# 			XD.MM08..LHZ, XD.MN07..BHZ, XD.MN07..HHZ, XD.MN07..LHZ

# %%
# Loop over events and create picks for each channel based on distance of the station from source
# and a very simple assumption of 5 km/s wave speed. Could be more fancy by doing wave tracing
# through an actual velocity structure, but I'm just doing a rough first pass.

p_vel = 5000  # m/s 
for event in catalog:
    picks = []
    for channel in inventory.get_contents()['channels']:
        # XD (iMUSH deployment) broadbands have LHZ, BHZ, and HHZ channels; we only need HHZ
        if channel[:2] != 'XD' or (channel[:2] == 'XD' and channel[-3:] == 'HHZ'):
            distance = np.sqrt(gps2dist_azimuth(
                event.origins[0].latitude,
                event.origins[0].longitude,
                inventory.get_channel_metadata(channel)['latitude'],
                inventory.get_channel_metadata(channel)['longitude']
            )[0]**2 + (event.origins[0].depth + inventory.get_channel_metadata(channel)['elevation'])**2)
            picks += [
                Pick(
                    time=event.origins[0].time +  distance/p_vel,
                    waveform_id=WaveformStreamID(
                        network_code=channel.split('.')[0],
                        station_code=channel.split('.')[1],
                        channel_code=channel.split('.')[3],
                        location_code=channel.split('.')[2],
                    ),
                    phase_hint='P'
                )
            ]
    event.picks = picks

# %%
# Make the templates with eqcorrscan

# We're constructing templates with a 10-second window to capture P and S with a bit of filtering.
# These can all be adjusted but should match the filtering and processing length you plan to use to
# scan through the continuous data. 

# There are a lot of stations and quite a few possible channels (40+)... we can reduce the search space if needed

tribe = Tribe().construct(
    method="from_client",
    client_id="IRIS",
    catalog=catalog,
    lowcut=1.0,
    highcut=10.0,
    samp_rate=50.0,
    filt_order=4,
    length=10.0,
    prepick=1,
    process_len=86400,
    all_horiz=False,
    parallel=True,
    min_snr=3.0,
)

# Ignore the warnings!
# Out:
# No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Found no data for this station: {'network': 'CC', 'station': 'JRO', 'location': '*', 'channel': 'BHZ', 'starttime': UTCDateTime(2014, 7, 17, 5, 0, 20, 110000), 'endtime': UTCDateTime(2014, 7, 18, 5, 0, 20, 110000)}
# No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Found no data for this station: {'network': 'XD', 'station': 'MG07', 'location': '*', 'channel': 'HHZ', 'starttime': UTCDateTime(2014, 7, 17, 5, 0, 20, 110000), 'endtime': UTCDateTime(2014, 7, 18, 5, 0, 20, 110000)}
# Signal-to-noise ratio 2.33120130909806 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.4196063653921476 below threshold for STD.BHZ, not using
# No pick for CC.STD..BHZ
# Signal-to-noise ratio 2.712679654905657 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 0.025523335415546234 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 0.026713642047067204 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.345880091304319 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 0.04577708504187219 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.4549903481103863 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 0.17022278976708213 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.59503804415293 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.6115595743247715 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.0906689334984114 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.443080707459951 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.479793328415157 below threshold for SHW.EHZ, not using
# No pick for UW.SHW..EHZ
# Signal-to-noise ratio 2.3766725705406615 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.7739609587870553 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 1.570311609090158 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.744871120546698 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 2.9607294646271343 below threshold for MI07.HHZ, not using
# No pick for XD.MI07..HHZ
# Signal-to-noise ratio 0.30065466443682487 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.9985191175261163 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 1.0605830093605682 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.5628403343223427 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.9713562377866043 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.764247768601586 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.9278816646577686 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.8170966123886387 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 0.9498746114493906 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.8873585671253115 below threshold for STD.BHZ, not using
# No pick for CC.STD..BHZ
# Signal-to-noise ratio 2.2340535238630164 below threshold for SUG.EHZ, not using
# No pick for CC.SUG..EHZ
# Signal-to-noise ratio 2.2904202519836665 below threshold for SWF2.BHZ, not using
# No pick for CC.SWF2..BHZ
# Signal-to-noise ratio 1.8838964363524693 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 1.485400759243775 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.9310802324885357 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.2257431853967575 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.821986968225181 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.6109559859311857 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 1.692923052028117 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.285219941459804 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 1.2923701470607023 below threshold for EDM.EHZ, not using
# No pick for UW.EDM..EHZ
# Signal-to-noise ratio 0.6324958869086122 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.3354129275847426 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.421276553167262 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio -0.8677105894408809 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 1.8274128931828917 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.4100555913429695 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 1.4113385191996792 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.0618242610202855 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.504950687324905 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.333442041566338 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.6601452311341047 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.657193803097787 below threshold for SWF2.BHZ, not using
# No pick for CC.SWF2..BHZ
# Signal-to-noise ratio 1.2676217964341225 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.663136553960853 below threshold for B202.EHZ, not using
# No pick for PB.B202..EHZ
# Signal-to-noise ratio 0.9012566209452169 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.5806064891539866 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.7611378791108026 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 1.804877326917351 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 1.3276221908751655 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.913247712954734 below threshold for EDM.EHZ, not using
# No pick for UW.EDM..EHZ
# Signal-to-noise ratio 1.0457230995591416 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 1.5020943265565592 below threshold for HSR.EHZ, not using
# No pick for UW.HSR..EHZ
# Signal-to-noise ratio 2.625954386175411 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.760222704804938 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio -0.8863476401849144 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.5881176385615006 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.970591571615765 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.9946717741961189 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.6217011888703974 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 0.8236114879221494 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.5210949092795514 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.9780808558240475 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 1.842424514799151 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.9299964211101432 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.598776205735924 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.5605851369212327 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.8522385835214306 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.305654739925259 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 2.488240845721735 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 2.956094175786913 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.5608962328074005 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 1.0987854551920055 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.9808805930251838 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.9174105412818236 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.930020694727006 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.6562229946604514 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 1.559384292997303 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.8747300170863834 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.449695021542131 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 1.1110608693859394 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 1.9185715257686444 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 1.6063698938764108 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.5951073552328463 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio 0.9602451985196542 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.423125368368656 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.3484435260962413 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.8201579673906374 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.4696682997064083 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.6157082626325208 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.1091539725287225 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.3110945784470784 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.328116158988472 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.5076336474644958 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.8379588134638603 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 2.2256333798863364 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 1.847164420212565 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.707194279646344 below threshold for EDM.EHZ, not using
# No pick for UW.EDM..EHZ
# Signal-to-noise ratio 2.613349855851261 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.7005718407545185 below threshold for HSR.EHZ, not using
# No pick for UW.HSR..EHZ
# Signal-to-noise ratio 2.8978585903438043 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.5431154467383097 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.482129471179817 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.2767676368136227 below threshold for SOS.EHZ, not using
# No pick for UW.SOS..EHZ
# Signal-to-noise ratio 2.7328751202801356 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 0.6644212503467668 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 0.7679613994582482 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.421726363088969 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.87541728675535 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 0.37960831315615406 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 1.6937378633415674 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.2655050820078753 below threshold for MI07.HHZ, not using
# No pick for XD.MI07..HHZ
# Signal-to-noise ratio 1.7240345498549954 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.5573656617446425 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.9910994627373086 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 1.157358245858112 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.331101790475804 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 2.063973091121346 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.5336383842651267 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.9314471486343967 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.9424051572691985 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.8374557520001287 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.1057786688275404 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 1.523799086790789 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.4914238878354142 below threshold for SWF2.BHZ, not using
# No pick for CC.SWF2..BHZ
# Signal-to-noise ratio 2.875363219308543 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.540354081677686 below threshold for B201.EHZ, not using
# No pick for PB.B201..EHZ
# Signal-to-noise ratio 1.785379860629217 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 1.5959568565202336 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.6107460611908637 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.189854020660533 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.4066326522142627 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 2.5435965452127443 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.588203914870088 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.48448302221747 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.104923537532382 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 0.2717527639947076 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.670595364761678 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.9106832438606323 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.6872039633883456 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 0.647576854048055 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.608062483713044 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.7176630040467855 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.5860049558202918 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.363788762434059 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.8374191831618294 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.4051152348740388 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 0.5809222567357166 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 1.2672394955127173 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.7514164986905914 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.731369653097552 below threshold for B202.EHZ, not using
# No pick for PB.B202..EHZ
# Signal-to-noise ratio 1.998195776909266 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 1.913693753842791 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.7674527120294954 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 1.7793830201181733 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.7684027067190886 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.9586869375750346 below threshold for HSR.EHZ, not using
# No pick for UW.HSR..EHZ
# Signal-to-noise ratio 2.554159861154154 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.3380840571387385 below threshold for SHW.EHZ, not using
# No pick for UW.SHW..EHZ
# Signal-to-noise ratio 0.848664475460331 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 0.148603778924794 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.364182829642337 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.167211798995264 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio -1.0004380643754147 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.6536265157358234 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.2595902185833756 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.8940739926698202 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.1310344184717325 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.541779018807404 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.34214858626352 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 0.5725826837148552 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.764807631902867 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.083757385963768 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.050160309150262 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.7316884849292493 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.9183990440520033 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.868146406821942 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.037590222050862 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 2.7311621568427964 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 2.6225215585517887 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.374860305985445 below threshold for B201.EHZ, not using
# No pick for PB.B201..EHZ
# Signal-to-noise ratio 2.365146573921855 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 1.4777844867107643 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.70618657169689 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.0195790315190651 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.8267312271596943 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.795803968971241 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.850473960529461 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.9136380235706953 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.956882205975698 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.787301596662994 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.133923248931918 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.9480358173151164 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# /Users/sophiaparafina/miniconda3/lib/python3.12/site-packages/eqcorrscan/core/template_gen.py:855: RuntimeWarning: invalid value encountered in scalar divide
#   max(tr_cut.data) / noise_amp < min_snr:
# Signal-to-noise ratio 2.974160846415611 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 1.7087185259459299 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 0.27619616973485817 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 1.7486815904510535 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 1.7502396867753351 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.697178805842932 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.721461043311429 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.4147374761751688 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.804574000407952 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.9926910731550107 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.589231615917195 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.1070416747505625 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.223795262741668 below threshold for SUG.EHZ, not using
# No pick for CC.SUG..EHZ
# Signal-to-noise ratio 2.0097102528896165 below threshold for SWF2.BHZ, not using
# No pick for CC.SWF2..BHZ
# Signal-to-noise ratio 2.937600654760633 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 2.8537108074129987 below threshold for B201.EHZ, not using
# No pick for PB.B201..EHZ
# Signal-to-noise ratio 1.4632875959959322 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 1.6419360041130688 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.3421994100915797 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.850754040552205 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 1.962886277243097 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 1.68720057521518 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.67306317725255 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.4974474900332697 below threshold for SHW.EHZ, not using
# No pick for UW.SHW..EHZ
# Signal-to-noise ratio 2.5625366264343206 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.7914246141570906 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.472361112869495 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 1.6374669692440587 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.736686029483294 below threshold for MI05.HHZ, not using
# No pick for XD.MI05..HHZ
# Signal-to-noise ratio 2.519450195999232 below threshold for MI07.HHZ, not using
# No pick for XD.MI07..HHZ
# Signal-to-noise ratio 2.042161061050749 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.546654641577714 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.9443995281834536 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 0.6642346681283485 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 1.7788618305264075 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 0.20197137888177039 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.2437717498052097 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.7819017277655833 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.5030381129442323 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.830389487456245 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 1.6705500495736918 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 1.3356530977165662 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 2.1280571530858343 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.0532838207621211 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 1.935643490798256 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 1.4814677089696542 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.7636138137755288 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.8404885173244603 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 2.408562084720895 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.478297937119321 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.605927150301743 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 1.9636138851763407 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.8947360678333283 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 1.6465989503880065 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 0.9065780866441235 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.7365391798615777 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 1.3954563426588245 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.4315678322267456 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.5873053724221227 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.7867816185469785 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 1.8876024168946948 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.203446147191355 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.8732198995533134 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 2.7750085948907803 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.3407597877150663 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.5331517334040226 below threshold for SWF2.BHZ, not using
# No pick for CC.SWF2..BHZ
# Signal-to-noise ratio 2.2116583678279165 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 1.8695683136216947 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.750167761158751 below threshold for B202.EHZ, not using
# No pick for PB.B202..EHZ
# Signal-to-noise ratio 2.828956370916242 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.3721445947033315 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.9194811401754484 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.5942787376633962 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.2315650154229116 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.0696743133468587 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 2.8344073198207447 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 1.9411832446591935 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.3159375881186435 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.195307530559525 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.5647463996694886 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.909836162772938 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 1.5742475398375795 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.929563577883169 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.5383386109078456 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 1.4797591852865108 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.9004505874612803 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio 0.4784011825215929 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.885978715631105 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 2.119104048794315 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 1.689542670517668 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.7226511027160347 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.62287707481636 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.271048351937359 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.301349136022164 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.6117388654365388 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 1.8296710474843898 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.689303286319941 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 1.8645356304500915 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 1.725521255193682 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.380442387891234 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.1366361741410842 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.5421607826518975 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.3578127318929685 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 2.293599939608991 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.203774016948802 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.0905556591686403 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.9487738842725415 below threshold for SOS.EHZ, not using
# No pick for UW.SOS..EHZ
# Signal-to-noise ratio 2.6258135731330117 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.399728768275813 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.5901693606102905 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 1.8946035126573408 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 1.5338173822667192 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.927161992032773 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.3862567834872634 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 1.9130076563558145 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.3902135422270323 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 2.525351193841773 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio -0.5699774200532374 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.194172266753766 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.687036569408887 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.5894626593243877 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.4308559848973217 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.2895211348061237 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.1444553048757635 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 1.9696739030501735 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 1.663797868358309 below threshold for SEP.EHZ, not using
# No pick for CC.SEP..EHZ
# Signal-to-noise ratio 2.802706067062935 below threshold for SUG.EHZ, not using
# No pick for CC.SUG..EHZ
# Signal-to-noise ratio 2.5667851635161067 below threshold for VALT.BHZ, not using
# No pick for CC.VALT..BHZ
# Signal-to-noise ratio 0.9750638686161535 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.7938045715084425 below threshold for B202.EHZ, not using
# No pick for PB.B202..EHZ
# Signal-to-noise ratio 0.9375975417138223 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.5904221841774033 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 1.630738125090673 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.594046321033327 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 2.344546000022504 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.5423890996898013 below threshold for ELK.EHZ, not using
# No pick for UW.ELK..EHZ
# Signal-to-noise ratio 2.704481294170676 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 2.6335425576652596 below threshold for HSR.EHZ, not using
# No pick for UW.HSR..EHZ
# Signal-to-noise ratio 2.6475499711097776 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.7874477353573854 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.261053424245447 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.857296003090599 below threshold for SHW.EHZ, not using
# No pick for UW.SHW..EHZ
# Signal-to-noise ratio 1.035843251341751 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.061135751705475 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.5828033737642495 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 1.9595930511955353 below threshold for MG05.HHZ, not using
# No pick for XD.MG05..HHZ
# Signal-to-noise ratio 2.10773832883231 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.6098933980511982 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.7287839662632734 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.626197886846507 below threshold for MI05.HHZ, not using
# No pick for XD.MI05..HHZ
# Signal-to-noise ratio 2.8992825851655963 below threshold for MI07.HHZ, not using
# No pick for XD.MI07..HHZ
# Signal-to-noise ratio 2.47199807693084 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 2.742525622780483 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio -0.003777995950733855 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.5083800296332934 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.8014849858686444 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.5429198052334185 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.3739563016220493 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.6618205758290436 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.3959339663879895 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Found no data for this station: {'network': 'CC', 'station': 'JRO', 'location': '*', 'channel': 'BHZ', 'starttime': UTCDateTime(2014, 7, 18, 6, 5, 45, 470000), 'endtime': UTCDateTime(2014, 7, 19, 6, 5, 45, 470000)}
# No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Found no data for this station: {'network': 'XD', 'station': 'MG07', 'location': '*', 'channel': 'HHZ', 'starttime': UTCDateTime(2014, 7, 18, 6, 5, 45, 470000), 'endtime': UTCDateTime(2014, 7, 19, 6, 5, 45, 470000)}
# Signal-to-noise ratio 0.031078706927210573 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 0.06077278334499762 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 0.02395619919521153 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 0.031461775684427075 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.1794901109442506 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.9134143138541577 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.9306070706003777 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.6663289532277084 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.883069241265488 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.339142971192504 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 1.1581674874304275 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.790480212856177 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 1.2842424186127213 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 2.511532359857363 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.2108153540919604 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.285050803604397 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.6410832834480082 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.9705896437190944 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 0.9792522020555758 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.157589340711376 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.8407506609439257 below threshold for B203.EHZ, not using
# No pick for PB.B203..EHZ
# Signal-to-noise ratio 2.1395521828775332 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.9028944791682476 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 1.852954132166193 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.44931450672605 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.617711795689981 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.5374273847712567 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.929051867079179 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.6032778539107113 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.4007939363246003 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.1521147592242102 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 2.2685327776930424 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.786195314400375 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 0.9663980388257264 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.4213851340742676 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.8310492462342913 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 2.684318427313749 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.461858015461027 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 1.3655582413602059 below threshold for MK04.HHZ, not using
# No pick for XD.MK04..HHZ
# Signal-to-noise ratio 2.867190166981676 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.06606277864571 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.22548154868317 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.1633529596085483 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.498917403827553 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.443464064697658 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ
# Signal-to-noise ratio 2.468164621759734 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# Signal-to-noise ratio 2.0488705551398327 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.2696359921403664 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 1.4144544903072362 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 2.786824029366591 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 1.0757333785016352 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.3145842512763544 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.121723206037124 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.205164869485194 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.9312648729645248 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.722242972205409 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.1381912504801983 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.7048954944984187 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.756632583722103 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.2071369933055953 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.32024061288337 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.6441610231668036 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 1.9435219690041032 below threshold for STD.BHZ, not using
# No pick for CC.STD..BHZ
# Signal-to-noise ratio 1.1920005529470243 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 2.756093587850959 below threshold for B202.EHZ, not using
# No pick for PB.B202..EHZ
# Signal-to-noise ratio 2.13296883449524 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 2.372596296192051 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.6168851038907743 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.8561684090192343 below threshold for CDF.EHZ, not using
# No pick for UW.CDF..EHZ
# Signal-to-noise ratio 2.4213745392312243 below threshold for FL2.EHZ, not using
# No pick for UW.FL2..EHZ
# Signal-to-noise ratio 1.7237647815031487 below threshold for LVP.EHZ, not using
# No pick for UW.LVP..EHZ
# Signal-to-noise ratio 2.0796629390294097 below threshold for SOS.EHZ, not using
# No pick for UW.SOS..EHZ
# Signal-to-noise ratio 2.627789402073178 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.2835953077729787 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.948295734612166 below threshold for MF05.HHZ, not using
# No pick for XD.MF05..HHZ
# Signal-to-noise ratio 2.5323513988350475 below threshold for MG03.HHZ, not using
# No pick for XD.MG03..HHZ
# Signal-to-noise ratio 1.4275032404659838 below threshold for MG06.HHZ, not using
# No pick for XD.MG06..HHZ
# Signal-to-noise ratio 2.45746021667084 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.1460313106409217 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 0.7810854434982704 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 2.6178390272157217 below threshold for MI04.HHZ, not using
# No pick for XD.MI04..HHZ
# Signal-to-noise ratio 2.9008609086535557 below threshold for MI05.HHZ, not using
# No pick for XD.MI05..HHZ
# Signal-to-noise ratio 2.9873349711908146 below threshold for MI07.HHZ, not using
# No pick for XD.MI07..HHZ
# Signal-to-noise ratio 2.929245435375606 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 2.892511625082434 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.2616913015230455 below threshold for MJ06.HHZ, not using
# No pick for XD.MJ06..HHZ
# Signal-to-noise ratio 1.8808058331469255 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio 1.777787418699118 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.20017338216414 below threshold for MK07.HHZ, not using
# No pick for XD.MK07..HHZ
# Signal-to-noise ratio 2.291539222909092 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 2.6246042685136413 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.2723496568362247 below threshold for ML09.HHZ, not using
# No pick for XD.ML09..HHZ
# Signal-to-noise ratio 2.4223737493226896 below threshold for MM04.HHZ, not using
# No pick for XD.MM04..HHZ
# Signal-to-noise ratio 2.8822459823162774 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.712382696502909 below threshold for MN07.HHZ, not using
# No pick for XD.MN07..HHZ
# No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Found no data for this station: {'network': 'CC', 'station': 'JRO', 'location': '*', 'channel': 'BHZ', 'starttime': UTCDateTime(2014, 7, 25, 16, 56, 25, 80000), 'endtime': UTCDateTime(2014, 7, 26, 16, 56, 25, 80000)}
# Data for MG06.HHZ is 7.059699999999999 hours long, which is less than 80 percent of the desired length, will not use
# Signal-to-noise ratio 0.1634806321148527 below threshold for B201.LHZ, not using
# No pick for PB.B201..LHZ
# Signal-to-noise ratio 0.03141862901240173 below threshold for B202.LHZ, not using
# No pick for PB.B202..LHZ
# Signal-to-noise ratio 0.039896067924405615 below threshold for B203.LHZ, not using
# No pick for PB.B203..LHZ
# Signal-to-noise ratio 1.9099206155822455 below threshold for B204.EHZ, not using
# No pick for PB.B204..EHZ
# Signal-to-noise ratio 0.026724233902561886 below threshold for B204.LHZ, not using
# No pick for PB.B204..LHZ
# Signal-to-noise ratio 2.912689876241267 below threshold for JUN.EHZ, not using
# No pick for UW.JUN..EHZ
# Signal-to-noise ratio 2.4951498918673622 below threshold for MTM.EHZ, not using
# No pick for UW.MTM..EHZ
# Signal-to-noise ratio 2.6599504322457657 below threshold for STD.EHZ, not using
# No pick for UW.STD..EHZ
# Signal-to-noise ratio 2.6651528823766006 below threshold for TDL.EHZ, not using
# No pick for UW.TDL..EHZ
# Signal-to-noise ratio 2.549976382409692 below threshold for MG08.HHZ, not using
# No pick for XD.MG08..HHZ
# Signal-to-noise ratio 2.784347446510853 below threshold for MH04.HHZ, not using
# No pick for XD.MH04..HHZ
# Signal-to-noise ratio 2.1724614397424364 below threshold for MH07.HHZ, not using
# No pick for XD.MH07..HHZ
# Signal-to-noise ratio 2.463193279365804 below threshold for MI05.HHZ, not using
# No pick for XD.MI05..HHZ
# Signal-to-noise ratio 2.5906915269028987 below threshold for MI08.HHZ, not using
# No pick for XD.MI08..HHZ
# Signal-to-noise ratio 2.7047058625104916 below threshold for MI09.HHZ, not using
# No pick for XD.MI09..HHZ
# Signal-to-noise ratio 2.2036433528083506 below threshold for MJ07.HHZ, not using
# No pick for XD.MJ07..HHZ
# Signal-to-noise ratio 1.5819638475048463 below threshold for MJ09.HHZ, not using
# No pick for XD.MJ09..HHZ
# Signal-to-noise ratio 2.381056038349569 below threshold for MK06.HHZ, not using
# No pick for XD.MK06..HHZ
# Signal-to-noise ratio 2.4690218758250553 below threshold for MK08.HHZ, not using
# No pick for XD.MK08..HHZ
# Signal-to-noise ratio 1.6246151518680347 below threshold for ML07.HHZ, not using
# No pick for XD.ML07..HHZ
# Signal-to-noise ratio 2.793104837840363 below threshold for MM06.HHZ, not using
# No pick for XD.MM06..HHZ
# Signal-to-noise ratio 2.9540421871443567 below threshold for MM08.HHZ, not using
# No pick for XD.MM08..HHZ

# %% [markdown]
# ## Detection!
#
# Now we run the templates through continuous data and see what wasn't located by the network. There's a *lot* going on under the hood here...

# %%
party = tribe.client_detect(
    client=client,
    starttime=UTCDateTime(2014,7,15),
    endtime=UTCDateTime(2014,8,10),
    threshold=10,
    threshold_type="MAD",
    trig_int=1.0,
    concurrent_processing=True,
)
# Out:
# Streams in queue will be edited in-place, you should not re-use them
# Last bit of data between 2014-07-15T23:59:59.998400Z and 2014-07-16T00:00:20.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Removed data for XD.MI07..HHZ XD.MK06..HHZ XD.ML09..HHZ due to less than 80% of the required length.
# Last bit of data between 2014-07-16T23:59:53.069500Z and 2014-07-17T00:00:13.505000Z will go unused because it is shorter than a chunk of 86400.0 s
# Out-of-range correlation in C-code, see WARNING from C-code.You are STRONGLY RECOMMENDED to check your data for spikes, clipping or non-physical artifacts
# Last bit of data between 2014-07-17T23:59:46.976167Z and 2014-07-18T00:00:07.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-18T23:59:40.069500Z and 2014-07-19T00:00:00.485000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-19T23:59:33.958400Z and 2014-07-19T23:59:54.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Removed data for XD.MG06..HHZ due to less than 80% of the required length.
# Last bit of data between 2014-07-20T23:59:27.069500Z and 2014-07-20T23:59:47.465000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-21T23:59:20.938400Z and 2014-07-21T23:59:41.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-22T23:59:14.069500Z and 2014-07-22T23:59:34.445000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-23T23:59:07.918400Z and 2014-07-23T23:59:28.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Removed data for XD.MG06..HHZ due to more zero datapoints than non-zero.
# Last bit of data between 2014-07-24T23:59:01.069500Z and 2014-07-24T23:59:21.425000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-25T23:58:54.898400Z and 2014-07-25T23:59:15.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Removed data for XD.MG06..HHZ due to more zero datapoints than non-zero.
# Last bit of data between 2014-07-26T23:58:48.069500Z and 2014-07-26T23:59:08.405000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-27T23:58:41.878400Z and 2014-07-27T23:59:02.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-28T23:58:35.069500Z and 2014-07-28T23:58:55.385000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-29T23:58:28.858400Z and 2014-07-29T23:58:49.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-30T23:58:22.069500Z and 2014-07-30T23:58:42.365000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-07-31T23:58:15.838400Z and 2014-07-31T23:58:36.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-01T23:58:09.069500Z and 2014-08-01T23:58:29.345000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-02T23:58:02.818400Z and 2014-08-02T23:58:23.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-03T23:57:56.069500Z and 2014-08-03T23:58:16.325000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-04T23:57:49.798400Z and 2014-08-04T23:58:10.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-05T23:57:43.069500Z and 2014-08-05T23:58:03.305000Z will go unused because it is shorter than a chunk of 86400.0 s
# /Users/sophiaparafina/miniconda3/lib/python3.12/site-packages/obspy/core/trace.py:2302: UserWarning: List of processing information in Trace.stats.processing reached maximal length of 100 entries.
#   warnings.warn(msg.format(self._max_processing_info))
# Last bit of data between 2014-08-06T23:57:36.778400Z and 2014-08-06T23:57:57.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-07T23:57:30.069500Z and 2014-08-07T23:57:50.285000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-08T23:57:23.758400Z and 2014-08-08T23:57:44.069500Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-09T23:57:17.069500Z and 2014-08-09T23:57:37.265000Z will go unused because it is shorter than a chunk of 86400.0 s
# Last bit of data between 2014-08-10T23:57:10.738400Z and 2014-08-10T23:57:31.069500Z will go unused because it is shorter than a chunk of 86400.0 s

# %%
party.plot(plot_grouped=True)
party.plot(plot_grouped=False)

print(f'Number of templates: {len(tribe)}')
print(f'Number of additional detections: {len(party)-len(tribe)}')
# Out:
# Number of templates: 18
# Number of additional detections: 58

# %% [markdown]
# So, we've added some additional detections, though not a lot. Note that two of the templates (2014-07-17T20:24:49 and the unlocated one we added at 2014-07-25T16:57:55) are matching the most events by themselves. There are also templates that are matching each other, but we don't count those as additional detections since we're requiring that detections have to be at least 1 second apart from each other (`trig_int`).

# %% [markdown]
# ## Other thoughts...
#
# From here, I think you could take a few detections and try to plot up data from the nodal arrays that were out and make record sections or something. I tried to only search in dates that were around the time of the nodal deployment so you have a good chance of getting a few detections/events at those times. Actually looking at the data is important, and is not something I've done much recently in the scope of this package.
#
# Good luck! Hopefully this is enough to give you a good start.
